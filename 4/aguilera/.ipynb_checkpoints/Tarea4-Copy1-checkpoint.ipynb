# %% [markdown]
# # TAREA 4. Limpeza de Datos e Implementación de NN para Clasificación
# > **Mauricio Montanares**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#cargamos la data
dataset = pd.read_excel('IrisSetosaT4.xlsx')

# %% [markdown]
# # Analisis del Dataset

# %% [markdown]
# ##### Tamaño

# %%
dataset.shape
# Out:
# (156, 11)

# %% [markdown]
# > 156 filas, 9 columnas

# %% [markdown]
# ## Primera vista al contenido del Dataset

# %%
info=dataset.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Species_No    156 non-null    int64
#  1   Petal_width   146 non-null    float64
#  2   Comp2         156 non-null    object
#  3   Petal_length  155 non-null    float64
#  4   Comp1         152 non-null    float64
#  5   Sepal_width   155 non-null    float64
#  6   Sepal_length  155 non-null    float64
#  7   Comp2.1       152 non-null    float64
#  8   Comp3         155 non-null    float64
#  9   Species_name  155 non-null    object
#  10  Obs           151 non-null    object
# dtypes: float64(7), int64(1), object(3)
# memory usage: 13.5+ KB

# %% [markdown]
# > Notamos que existen columnas con diferentes tipos de datos, numericos como no numericos.
#
# > Algunas columnas presentan elementos nulos.

# %%
#descripcion de las columnas con datos del tipo numerico (float64, int64)
dataset.describe()
# Out:
#        Species_No  Petal_width  Petal_length       Comp1  Sepal_width  \
# count  156.000000   146.000000    155.000000  152.000000   155.000000
# mean     2.012821     1.227397      3.856774    4.069737     3.036129
# std      0.819025     0.896470      2.302935    2.320825     0.757721
# min      1.000000     0.000000      0.000000    0.200000     0.000000
# 25%      1.000000     0.300000      1.550000    1.775000     2.800000
# 50%      2.000000     1.300000      4.300000    4.550000     3.000000
# 75%      3.000000     1.800000      5.100000    5.300000     3.350000
# max      3.000000     5.600000     20.500000   20.700000     8.700000
#
#        Sepal_length     Comp2.1       Comp3
# count    155.000000  152.000000  155.000000
# mean       5.667742    5.646711   11.569484
# std        1.562878    1.571009    6.041595
# min       -5.000000   -5.000000    0.000000
# 25%        5.100000    5.100000    6.120000
# 50%        5.700000    5.700000   12.180000
# 75%        6.400000    6.400000   15.745000
# max       10.200000   10.200000   32.860000

# %%
#visualizacion de los primeros elementos del dataset
dataset.head()
# Out:
#    Species_No  Petal_width Comp2  Petal_length  Comp1  Sepal_width  \
# 0           1          0.2  0.14           1.4    1.6          3.5
# 1           1          0.2  0.14           1.4    1.6          3.0
# 2           1          NaN  0.14           1.3    1.5          3.2
# 3           1          NaN  0.14           1.5    1.7          3.1
# 4           1          NaN  0.14           1.4    NaN          3.6
#
#    Sepal_length  Comp2.1  Comp3 Species_name    Obs
# 0           5.1      5.1   5.60       Setosa  James
# 1           4.9      4.9   4.80       Setosa  James
# 2           4.7      4.7   4.80       Setosa  James
# 3           4.6      4.6   5.27       Setosa  James
# 4           5.0      5.0   0.00       Setosa  Peter

# %% [markdown]
# > Notamos que la columa 'Comp2' contiene informacion numerica pero almacenada como str. Debemos convertir estos datos.
#
# > Sepal_length y Comp2.1 se ven sospechosamente similares, al menos en head. Lo analizaremos en detalle mas adelante.

# %%
compare = dataset['Sepal_length'] == dataset['Comp2.1']

true, false = 0, 0
for i in range(len(compare)):
    if compare[i] == True:
        true += 1
    else:
        false +=1
print("Cuantity of False:", false, "| Cuantity of True:", true)
# Out:
# Cuantity of False: 4 | Cuantity of True: 152

# %% [markdown]
# > Eliminamos la columna Comp2.1 por no aportar informacion relevante a la ya existente.

# %%
dataset.drop(labels=['Comp2.1'], axis = 1, inplace=True)

# %% [markdown]
# # Plots Iniciales (datos numericos)

# %%
#convertimos todos los elementos de str->float con exepcion de los nan
float_Comp2 = []
for i in dataset['Comp2']:
    if i != ' ': 
        float_Comp2 = [float(i)] + float_Comp2

# %%
#lo cargamos al dataset
dataset.drop(labels=['Comp2'], axis = 1, inplace=True)
dataset=pd.concat([dataset, pd.DataFrame(float_Comp2, columns=['Comp2'])], axis=1)

# %%
#Lines
plt.figure(figsize=(26, 35))

plt.subplot(421)
plt.plot(dataset['Petal_width'], color = 'salmon', label = 'Petal_width',linewidth = '3' )
plt.legend(fontsize=18)

plt.subplot(422)
plt.plot(dataset['Petal_length'], color = 'salmon', label = 'Petal_length',linewidth = '3' )
plt.legend(fontsize=18)

plt.subplot(423)
plt.plot(dataset['Sepal_width'], color = 'salmon', label = 'Sepal_width',linewidth = '3')
plt.legend(fontsize=18)

plt.subplot(424)
plt.plot(dataset['Sepal_length'], color = 'salmon', label = 'Sepal_length',linewidth = '3')
plt.legend(fontsize=18)

plt.subplot(425)
plt.plot(dataset['Comp1'], color = 'salmon', label = 'Comp1', linewidth = '3')
plt.legend(fontsize=18)

plt.subplot(426)
plt.plot(dataset['Comp2'], color = 'salmon', label = 'Comp2',linewidth = '3')
#plt.plot(float_Comp2, color = 'salmon', label = 'Comp2',linewidth = '3')
plt.legend(fontsize=18)

plt.subplot(427)
plt.plot(dataset['Comp3'], color = 'salmon', label = 'Comp3',linewidth = '3')
#plt.plot(float_Comp2, color = 'salmon', label = 'Comp2',linewidth = '3')
plt.legend(fontsize=18)

plt.show()

# %% [markdown]
# > A priemera vista se observan algunos datos faltantes. Por ejemplo en la grafica Petal_width
#
# > Notamos que valores asignados a metricas (length) poseen registros negativos. Consideramos estos datos como errores
#
# > Notamos que existen valores atipicos. Realizaremos un boxplot para visualizar los outliers

# %% [markdown]
# ## BoxPlot

# %%
import seaborn as sns  #lib for nice boxplots

# %%
plt.figure(figsize=(12, 15), dpi=150)

plt.subplot(421)
sns.boxplot(y=dataset['Petal_width'], palette="Greens")
plt.title('Petal width')
plt.ylim(-5,25)

plt.subplot(422)
sns.boxplot(y=dataset['Petal_length'], palette="Greens")
plt.title('Petal length')
plt.ylim(-5,25)

plt.subplot(423)
sns.boxplot(y=dataset['Sepal_width'], palette="Greens")
plt.title('Sepal width')
plt.ylim(-5,25)

plt.subplot(424)
sns.boxplot(y=dataset['Sepal_length'], palette="Greens")
plt.title('Sepal length')
plt.ylim(-5,25)

plt.subplot(425)
sns.boxplot(y=dataset['Comp1'], palette="Greens")
plt.title('Comp1')
plt.ylim(-5,25)

plt.subplot(426)
sns.boxplot(y=dataset['Comp2'], palette="Greens")
plt.ylim(-5,25)
plt.title('Comp2')

plt.subplot(427)
sns.boxplot(y=dataset['Comp3'], palette="Greens")
plt.ylim(-5,30)
plt.title('Comp2')

#plt.savefig('boxs.pdf')

plt.show()

# %% [markdown]
# > Observamos claramente los outliers

# %% [markdown]
# ## OUTLIERS
# > Utilizaremos Z score para identificarlos y corregirlos
#
# >Z score = (x-mean)/std.deviation

# %%
#funcion que almacena el valor de los outliers y la posicion de estos en el dataset.
#recibe como argumento el dataset, 'nombre_columna', valor de threshold(en base al z-score)
def find_positions_outliers(data, column, THRESHOLD):
    values_outliers = []
    positions_outliers = []
    
    mean = np.mean(data[column])
    std = np.std(data[column])
    for i in range(data.shape[0]):
        z = (data[column][i]-mean)/std
        if abs(z) > THRESHOLD:
            values_outliers.append(data[column][i])
            positions_outliers.append(i)
    
    
    return positions_outliers, values_outliers

# %%
columns_to_analize = ['Petal_width', 'Petal_length', 'Sepal_width', 'Sepal_length', 'Comp1', 'Comp2', 'Comp3']
THRESHOLD = 1.5 #sensibility
for i in columns_to_analize:
    print('=================================================')
    print('')
    print('Columna', i)
    print('Posiciones, Valores Outliers = ', find_positions_outliers(dataset, i, THRESHOLD))
    print('')
    print('=================================================')
# Out:
# =================================================
#
# Columna Petal_width
# Posiciones, Valores Outliers =  ([9, 67], [5.0, 5.6])
#
# =================================================
# =================================================
#
# Columna Petal_length
# Posiciones, Valores Outliers =  ([82, 112, 127, 145], [0.0, 20.5, 0.0, 10.4])
#
# =================================================
# =================================================
#
# Columna Sepal_width
# Posiciones, Valores Outliers =  ([9, 16, 34, 82, 112, 127], [8.7, 4.4, 4.2, 0.0, 0.0, 0.0])
#
# =================================================
# =================================================
#
# Columna Sepal_length
# Posiciones, Valores Outliers =  ([9, 67, 82, 112, 127, 139, 148], [0.1, 10.2, 0.0, 8.7, 0.0, 0.1, -5.0])
#
# =================================================
# =================================================
#
# Columna Comp1
# Posiciones, Valores Outliers =  ([82, 112, 127, 136, 145], [0.2, 20.7, 0.2, 0.2, 10.6])
#
# =================================================
# =================================================
#
# Columna Comp2
# Posiciones, Valores Outliers =  ([22, 86, 144], [-1.0, 3.9199999999999995, 3.5])
#
# =================================================
# =================================================
#
# Columna Comp3
# Posiciones, Valores Outliers =  ([4, 5, 6, 9, 82, 112, 113, 121, 127, 137, 145, 155], [0.0, 0.0, 0.0, 27.84, 0.0, 0.0, 22.68, 26.22, 0.0, 25.080000000000002, 32.86, 0.0])
#
# =================================================

# %% [markdown]
# > Si revisamos las graficas de lineas y boxplot veremos que hemos detectado correctamente los outliers y sus posiciones. Ahora podemos corregirlos.

# %% [markdown]
# ### Correcion de Outliers
# > Estos datos atipicos los reemplazaremos por la media de la columna correspondiente

# %%
#utilizamos la funcion find_positions_outliers para reemplazar los valores atipicos por la media de la columna correspondiente

columns_to_analize = ['Petal_width', 'Petal_length', 'Sepal_width', 'Sepal_length', 'Comp1', 'Comp2', 'Comp3']

THRESHOLD = 1.3
for i in columns_to_analize:
    positions = find_positions_outliers(dataset, i, THRESHOLD)[0]
    for j in positions:
        dataset[i][j] = np.mean(dataset[i])
# Out:
# <ipython-input-16-b847a361f81f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[i][j] = np.mean(dataset[i])

# %% [markdown]
# ### Nuevo LinesPlot
# > Con los datos corregidos volvemos a realizar los graficos de lineas

# %%
#Lines
plt.figure(figsize=(26, 35))

plt.subplot(421)
plt.plot(dataset['Petal_width'], color = 'salmon', label = 'Petal_width',linewidth = '3' )
plt.legend(fontsize=18)

plt.subplot(422)
plt.plot(dataset['Petal_length'], color = 'salmon', label = 'Petal_length',linewidth = '3' )
plt.legend(fontsize=18)

plt.subplot(423)
plt.plot(dataset['Sepal_width'], color = 'salmon', label = 'Sepal_width',linewidth = '3')
plt.legend(fontsize=18)

plt.subplot(424)
plt.plot(dataset['Sepal_length'], color = 'salmon', label = 'Sepal_length',linewidth = '3')
plt.legend(fontsize=18)

plt.subplot(425)
plt.plot(dataset['Comp1'], color = 'salmon', label = 'Comp1', linewidth = '3')
plt.legend(fontsize=18)

plt.subplot(426)
plt.plot(dataset['Comp2'], color = 'salmon', label = 'Comp2',linewidth = '3')
#plt.plot(float_Comp2, color = 'salmon', label = 'Comp2',linewidth = '3')
plt.legend(fontsize=18)

plt.subplot(427)
plt.plot(dataset['Comp3'], color = 'salmon', label = 'Comp3',linewidth = '3')
#plt.plot(float_Comp2, color = 'salmon', label = 'Comp2',linewidth = '3')
plt.legend(fontsize=18)

plt.show()

# %% [markdown]
# > Notamos que los valores negativos para width y length ya no estan presentes

# %% [markdown]
# ### Nuevo Boxplot
# > Con los datos corregidos volvemos a relizar un boxplot

# %%
plt.figure(figsize=(12, 15), dpi=150)

plt.subplot(421)
sns.boxplot(y=dataset['Petal_width'], palette="Greens")
plt.title('Petal width')
plt.ylim(-5,25)

plt.subplot(422)
sns.boxplot(y=dataset['Petal_length'], palette="Greens")
plt.title('Petal length')
plt.ylim(-5,25)

plt.subplot(423)
sns.boxplot(y=dataset['Sepal_width'], palette="Greens")
plt.title('Sepal width')
plt.ylim(-5,25)

plt.subplot(424)
sns.boxplot(y=dataset['Sepal_length'], palette="Greens")
plt.title('Sepal length')
plt.ylim(-5,25)

plt.subplot(425)
sns.boxplot(y=dataset['Comp1'], palette="Greens")
plt.title('Comp1')
plt.ylim(-5,25)

plt.subplot(426)
sns.boxplot(y=dataset['Comp2'], palette="Greens")
plt.ylim(-5,25)
plt.title('Comp2')

plt.subplot(427)
sns.boxplot(y=dataset['Comp3'], palette="Greens")
plt.ylim(-5,30)
plt.title('Comp2')

#plt.savefig('boxs.pdf')

plt.show()

# %% [markdown]
# > Notamos que los outliers presenten en el primer grafico de boxplot ya no estan presentes.

# %% [markdown]
# ## Elementos Nulos

# %%
print('Elementos Nulos por culumnas')
dataset.isna().sum()
# Out:
# Elementos Nulos por culumnas
# Species_No       0
# Petal_width     10
# Petal_length     1
# Comp1            4
# Sepal_width      1
# Sepal_length     1
# Comp3            1
# Species_name     1
# Obs              5
# Comp2            2
# dtype: int64

# %% [markdown]
# > Notamos que 8 de las 9 columnas presentan elementos nulos.

# %% [markdown]
# #### ¿Qué tipo de datos son los elementos faltantes?

# %%
dataset.dtypes
# Out:
# Species_No        int64
# Petal_width     float64
# Petal_length    float64
# Comp1           float64
# Sepal_width     float64
# Sepal_length    float64
# Comp3           float64
# Species_name     object
# Obs              object
# Comp2           float64
# dtype: object

# %% [markdown]
# > Notamos que la mayoria de las columnas con elementos nulos son del tipo numericas
#
# > Existen dos columnas 'Species_name' y 'Obs' del tipo no numericas que poseen elementos nulos.
#
# > **Es posible completar de alguna manera los elementos numericos faltantes(rellenar con la media, interpolacion, entre otras), pero los elementos no numericos
# deben ser revisados de manera individual para conocer exactamente que tipo de informacion contienen y si estos pueden o no pueden ser corregidos.**
#
# > Existe informacion en otras columnas que ayuden a rellenar los elementos faltantes?

# %% [markdown]
# ### Revision columnas 'Species_name' y 'Obs'

# %%
dataset[['Species_No','Species_name']]
# Out:
#      Species_No Species_name
# 0             1       Setosa
# 1             1       Setosa
# 2             1       Setosa
# 3             1       Setosa
# 4             1       Setosa
# ..          ...          ...
# 151           3    Verginica
# 152           3    Verginica
# 153           3    Verginica
# 154           3    Verginica
# 155           3    Verginica
#
# [156 rows x 2 columns]

# %%
print('Elementos presentes en "Species_No":', dataset['Species_No'].unique())
# Out:
# Elementos presentes en "Species_No": [1 2 3]

# %%
print('Elementos presentes en "Species_name":', dataset['Species_name'].unique())
# Out:
# Elementos presentes en "Species_name": [' Setosa' ' Versicolor' ' Verginica' nan]

# %% [markdown]
# > 'Species_name' Contiene el nombre de la especie.
#
# > 'Species_No' Contiene un numero identificador:
#
# >1 -> Setosa
#
# > 2 -> Versicolor
#
# > 3 -> Verginica
#
# > **Necesitamos conocer la posicion del elemento faltante en Species_name para relacionarlo con Species_No**

# %%
#creamos una funcion que nos indica la posicion exacta de los elementos faltantes.
#como argumento recibe un pd.frame y 'name_column'
def find_nan_pos(data, col_name):
    nan_pos = []
    count = 0;
    for x in data.index:
        try:
            if str(data[col_name][x]) == 'nan' or data[col_name][x] == 'NaN':
                nan_pos = nan_pos + [x]
              
        except:
            print(count, 'dropped')
            
    return print('Null elements positions:', nan_pos)

# %%
#test function
find_nan_pos(dataset, 'Comp1')
# Out:
# Null elements positions: [4, 5, 6, 155]

# %%
dataset[['Species_No','Species_name']].iloc[4]
# Out:
# Species_No            1
# Species_name     Setosa
# Name: 4, dtype: object

# %% [markdown]
# > El elemento nulo pertenece a la categoria 1. Por lo tanto el elemento nulo = 'Setosa'

# %%
dataset[['Species_No','Species_name']].iloc[5]
# Out:
# Species_No            1
# Species_name     Setosa
# Name: 5, dtype: object

# %% [markdown]
# > El elemento nulo pertenece a la categoria 1. Por lo tanto el elemento nulo = 'Setosa'

# %%
dataset[['Species_No','Species_name']].iloc[6]
# Out:
# Species_No            1
# Species_name     Setosa
# Name: 6, dtype: object

# %% [markdown]
# > El elemento nulo pertenece a la categoria 1. Por lo tanto el elemento nulo = 'Setosa'

# %%
dataset[['Species_No','Species_name']].iloc[155]
# Out:
# Species_No               3
# Species_name     Verginica
# Name: 155, dtype: object

# %%
dataset[['Species_No','Species_name']].iloc[136]
# Out:
# Species_No        3
# Species_name    NaN
# Name: 136, dtype: object

# %% [markdown]
# > El elemento nulo pertenece a la categoria 3. Por lo tanto el elemento nulo = 'Verginica'

# %%
#cambiamos el valor
dataset['Species_name'].iloc[4] = ' Setosa'
dataset['Species_name'].iloc[5] = ' Setosa' 
dataset['Species_name'].iloc[6] = ' Setosa'
dataset['Species_name'].iloc[136] = ' Verginica' 
dataset['Species_name'].iloc[155] = ' Verginica'
# Out:
# /home/mxmont/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#revisamos nuevamente los elementos nulos
dataset.isna().sum()
# Out:
# Species_No       0
# Petal_width     10
# Petal_length     1
# Comp1            4
# Sepal_width      1
# Sepal_length     1
# Comp3            1
# Species_name     0
# Obs              5
# Comp2            2
# dtype: int64

# %% [markdown]
# > Corroboramos que hermos eliminado los elementos nulos de 'Species_name'

# %% [markdown]
# #### Ahora analizamos la columna 'Obs'

# %%
dataset['Obs']
# Out:
# 0      James
# 1      James
# 2      James
# 3      James
# 4      Peter
#        ...
# 151    Peter
# 152    Peter
# 153    Peter
# 154    Peter
# 155    Peter
# Name: Obs, Length: 156, dtype: object

# %% [markdown]
# > Contiene nombre de los observadores. **No es posible autocompletar sin informacion adicional**

# %% [markdown]
# **Como no es posible completar de manera certera los elementos nulos de 'Obs'
# se procedera a elimnar las filas que contengan elementos nulos en estas dos columnas**

# %% [markdown]
# ## Dropna (for some columns)

# %%
dataset.shape
# Out:
# (156, 10)

# %%
dataset.isna().sum()
# Out:
# Species_No       0
# Petal_width     10
# Petal_length     1
# Comp1            4
# Sepal_width      1
# Sepal_length     1
# Comp3            1
# Species_name     0
# Obs              5
# Comp2            2
# dtype: int64

# %%
#eliminamos las filas que poseean elementos nulos en las columnas [Obs']
dataset.dropna(subset = ['Obs'], axis=0, inplace=True)

# %%
dataset.shape
# Out:
# (151, 10)

# %%
dataset.isna().sum()
# Out:
# Species_No       0
# Petal_width     10
# Petal_length     1
# Comp1            4
# Sepal_width      1
# Sepal_length     1
# Comp3            1
# Species_name     0
# Obs              0
# Comp2            2
# dtype: int64

# %% [markdown]
# > Los elementos nulos de 'Obs' ya no existen. Se han eliminado las filas donde estos estaban.

# %% [markdown]
# ## Fix Columnas del tipo Numericas
# > Analizamos la posicion de los elementos faltantes
#
# > Utilizaremos la media de las columnas con elementos nulos para rellenar los respectivos espacios sin datos. La media que se calculara no considera el total de datos, sino que dependera de la especie en cuestion.

# %% [markdown]
# #### Posición

# %%
print('========================= Petal_width =========================')
find_nan_pos(dataset, 'Petal_width')

print('========================= Petal_length =========================')
find_nan_pos(dataset, 'Petal_length')

print('========================= Comp1 =========================')
find_nan_pos(dataset, 'Comp1')

print('========================= Comp2 =========================')
find_nan_pos(dataset, 'Comp2')

print('========================= Comp3 =========================')
find_nan_pos(dataset, 'Comp3')

print('========================= Sepal_width =========================')
find_nan_pos(dataset, 'Sepal_width')

print('========================= Sepal_length =========================')
find_nan_pos(dataset, 'Sepal_length')
# Out:
# ========================= Petal_width =========================
# Null elements positions: [2, 3, 4, 5, 136, 141, 142, 143, 144, 145]
# ========================= Petal_length =========================
# Null elements positions: [136]
# ========================= Comp1 =========================
# Null elements positions: [4, 5, 6, 155]
# ========================= Comp2 =========================
# Null elements positions: [154, 155]
# ========================= Comp3 =========================
# Null elements positions: [136]
# ========================= Sepal_width =========================
# Null elements positions: [136]
# ========================= Sepal_length =========================
# Null elements positions: [136]

# %% [markdown]
# > Notamos que en la posicion 136 posee la mayoria de los elementos vacios. 'Comp1' y 'Comp2' son la excepcion.

# %% [markdown]
# > Para rellenar los datos faltantes de [Petal_width, Sepal_width, Sepal_length] vamos a considerar la media de los valores correspondientes a la especie en la posicion 136, es decir 'Verginica'
#
# > Para ['Petal_width', 'Comp2'] realizaremos algo simililar pero cada dato faltante se rellenera con la media de la especie correspondiente.

# %%
print('posicion 0: ', dataset['Species_name'][0])
print('posicion 1: ', dataset['Species_name'][1])
print('posicion 136: ', dataset['Species_name'][136])
print('posicion 141: ', dataset['Species_name'][141])
print('posicion 142: ', dataset['Species_name'][142])
print('posicion 143: ', dataset['Species_name'][143])
print('posicion 144: ', dataset['Species_name'][144])
print('posicion 145: ', dataset['Species_name'][145])
# Out:
# posicion 0:   Setosa
# posicion 1:   Setosa
# posicion 136:   Verginica
# posicion 141:   Verginica
# posicion 142:   Verginica
# posicion 143:   Verginica
# posicion 144:   Verginica
# posicion 145:   Verginica

# %% [markdown]
# #### Buscamos los datos pertenecientes solo a la especie 'Verginica' y 'Setosa'

# %%
#lista que almacena las posiciones de verginica
virginica_pos = []
for i in dataset.index:
    if dataset['Species_No'][i] == 3:
        virginica_pos = [i] + virginica_pos     
        
#lista que almacena las posiciones de setosa
setosa_pos = []
for i in dataset.index:
    if dataset['Species_No'][i] == 1:
        setosa_pos = [i] + setosa_pos

# %%
dataset.columns
# Out:
# Index(['Species_No', 'Petal_width', 'Petal_length', 'Comp1', 'Sepal_width',
#        'Sepal_length', 'Comp3', 'Species_name', 'Obs', 'Comp2'],
#       dtype='object')

# %%
#creamos listas que almacenen los datos de la especie 'Virginica'
petal_w = []
petal_l = []
sepal_w = []
sepal_l = []
comp1 = []
comp2 = []
comp3 = []
col = ['Petal_width', 'Petal_length', 'Comp1', 'Sepal_width',
       'Sepal_length', 'Comp2', 'Comp3'] #columnas a revisar dataset.columns

for i in col:
    for j in virginica_pos:       #virginica case
        if i == 'Petal_width':
            petal_w = [dataset[i][j]] + petal_w
        if i == 'Petal_length':
            petal_l = [dataset[i][j]] + petal_l
        if i == 'Comp1':
            comp1 = [dataset[i][j]] + comp1
        if i == 'Sepal_width':
            sepal_w = [dataset[i][j]] + sepal_w
        if i == 'Sepal_length':
            sepal_l = [dataset[i][j]] + sepal_l
        if i == 'Comp3':
            comp3 = [dataset[i][j]] + comp3
            
for i in col:
    for j in setosa_pos:          #setosa case            
        if i == 'Comp2':
            comp2 = [dataset[i][j]] + comp2

# %%
#Creamos una funcion que calcula el promedio de los valores de una lista(sin considerar los datos 'nan')
def average(lista):
    for i in range(len(lista)):
        if i == 0:
            clean_list = [] 
        if str(lista[i]) != 'nan' :
            clean_list = [lista[i]] + clean_list #guardamos
    return sum(clean_list)/len(clean_list)

# %% [markdown]
# ## Rellenamos los datos vacios
# > Utilizamos el promedio de las mediciones para cada columna correspondiente

# %%
dataset['Petal_width'].fillna(average(petal_w), inplace=True) #columna Petal_width  
dataset['Petal_length'].fillna(average(petal_l), inplace=True) #columna Petal_length
dataset['Sepal_width'].fillna(average(sepal_w), inplace=True) #columna Sepal_width
dataset['Sepal_length'].fillna(average(sepal_l), inplace=True) #columna Sepal_length
dataset['Comp1'].fillna(average(comp1), inplace=True) #columna Comp1
dataset['Comp2'].fillna(average(comp2), inplace=True) #columna Comp2
dataset['Comp3'].fillna(average(comp3), inplace=True) #columna Comp3

# %%
dataset.isna().sum()
# Out:
# Species_No      0
# Petal_width     0
# Petal_length    0
# Comp1           0
# Sepal_width     0
# Sepal_length    0
# Comp3           0
# Species_name    0
# Obs             0
# Comp2           0
# dtype: int64

# %% [markdown]
# > **NO EXISTEN ELEMENTOS NULOS**

# %% [markdown]
# # Rangos de las caracteristicas numericas

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Species_No    151 non-null    int64
#  1   Petal_width   151 non-null    float64
#  2   Petal_length  151 non-null    float64
#  3   Comp1         151 non-null    float64
#  4   Sepal_width   151 non-null    float64
#  5   Sepal_length  151 non-null    float64
#  6   Comp3         151 non-null    float64
#  7   Species_name  151 non-null    object
#  8   Obs           151 non-null    object
#  9   Comp2         151 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 18.0+ KB

# %%
species_names = dataset['Species_name'] #save this for the future

# %%
num_data = dataset[['Species_No', 'Petal_width', 'Petal_length', 'Comp1', 'Sepal_width',
       'Sepal_length', 'Comp2', 'Comp3']]

# %%
print("Minimos:")
print(num_data.min())
print('')
print("=============================")
print('')
print("Maximos:")
num_data.max()
# Out:
# Minimos:
# Species_No      1.00
# Petal_width     0.10
# Petal_length    1.00
# Comp1           1.20
# Sepal_width     2.10
# Sepal_length    4.30
# Comp2           0.07
# Comp3           3.90
# dtype: float64
#
# =============================
#
# Maximos:
# Species_No       3.00
# Petal_width      2.30
# Petal_length     6.70
# Comp1            6.90
# Sepal_width      4.00
# Sepal_length     7.60
# Comp2            1.68
# Comp3           19.32
# dtype: float64

# %% [markdown]
# > Visualzando los rangos maximos y minimos podemos notar que es necesario ajustar a la misma escala todas las caracteristicas (Numericas)

# %%
#importamos MinMaxScaler
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(num_data)
scaled_df = pd.DataFrame(scaled_df, columns=['Species_No', 'Petal_width', 'Petal_length', 'Comp1', 'Sepal_width',
       'Sepal_length', 'Comp2', 'Comp3'])

# %%
scaled_df
# Out:
#      Species_No  Petal_width  Petal_length     Comp1  Sepal_width  \
# 0           0.0     0.045455      0.070175  0.070175     0.736842
# 1           0.0     0.045455      0.070175  0.070175     0.473684
# 2           0.0     0.793780      0.052632  0.052632     0.578947
# 3           0.0     0.793780      0.087719  0.087719     0.526316
# 4           0.0     0.793780      0.070175  0.761299     0.789474
# ..          ...          ...           ...       ...          ...
# 146         1.0     1.000000      0.736842  0.736842     0.473684
# 147         1.0     0.818182      0.701754  0.701754     0.210526
# 148         1.0     0.863636      0.736842  0.736842     0.473684
# 149         1.0     1.000000      0.771930  0.771930     0.684211
# 150         1.0     0.772727      0.719298  0.761299     0.473684
#
#      Sepal_length     Comp2     Comp3
# 0        0.242424  0.739130  0.110246
# 1        0.181818  0.956522  0.058366
# 2        0.121212  0.782609  0.058366
# 3        0.090909  0.956522  0.088846
# 4        0.212121  0.484149  0.497372
# ..            ...       ...       ...
# 146      0.727273  0.043478  0.797665
# 147      0.606061  0.043478  0.590143
# 148      0.666667  0.043478  0.797665
# 149      0.575758  0.776583  0.981842
# 150      0.484848  0.776583  0.473956
#
# [151 rows x 8 columns]

# %%
print("Minimos:")
print(scaled_df.min())
print('')
print("=============================")
print('')
print("Maximos:")
scaled_df.max()
# Out:
# Minimos:
# Species_No      0.0
# Petal_width     0.0
# Petal_length    0.0
# Comp1           0.0
# Sepal_width     0.0
# Sepal_length    0.0
# Comp2           0.0
# Comp3           0.0
# dtype: float64
#
# =============================
#
# Maximos:
# Species_No      1.0
# Petal_width     1.0
# Petal_length    1.0
# Comp1           1.0
# Sepal_width     1.0
# Sepal_length    1.0
# Comp2           1.0
# Comp3           1.0
# dtype: float64

# %% [markdown]
# > **Datos Normalizados**

# %% [markdown]
# # CORRELACION

# %%
import seaborn as sn

# %%
#create corrmatrix
plt.figure(figsize=(15, 10))
corr_matrix = scaled_df.drop('Species_No', axis='columns').corr()

sn.heatmap(corr_matrix , annot=True)
#plt.savefig("corr_matrix.eps")
plt.show()

# %% [markdown]
# > Notamos que existe una correlacion total entre las columnas 'Comp1' y 'Petal_length'. Podemos eliminar una de estas dos.
#
# > Exise tamien una correlacion muy alta(>90%) entre 'Comp1'-'Petal_width'
#
# > Se descartaran las columnas 'Comp1'

# %%
scaled_df.drop(['Comp1'], axis='columns', inplace=True)

# %%
scaled_df
# Out:
#      Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0           0.0     0.045455      0.070175     0.736842      0.242424
# 1           0.0     0.045455      0.070175     0.473684      0.181818
# 2           0.0     0.793780      0.052632     0.578947      0.121212
# 3           0.0     0.793780      0.087719     0.526316      0.090909
# 4           0.0     0.793780      0.070175     0.789474      0.212121
# ..          ...          ...           ...          ...           ...
# 146         1.0     1.000000      0.736842     0.473684      0.727273
# 147         1.0     0.818182      0.701754     0.210526      0.606061
# 148         1.0     0.863636      0.736842     0.473684      0.666667
# 149         1.0     1.000000      0.771930     0.684211      0.575758
# 150         1.0     0.772727      0.719298     0.473684      0.484848
#
#         Comp2     Comp3
# 0    0.739130  0.110246
# 1    0.956522  0.058366
# 2    0.782609  0.058366
# 3    0.956522  0.088846
# 4    0.484149  0.497372
# ..        ...       ...
# 146  0.043478  0.797665
# 147  0.043478  0.590143
# 148  0.043478  0.797665
# 149  0.776583  0.981842
# 150  0.776583  0.473956
#
# [151 rows x 7 columns]

# %%
for x in range(scaled_df.shape[0]):
    
    if scaled_df.iloc[x,0] == 0.0:
        scaled_df.iloc[x,0] = int(0);
        
    if scaled_df.iloc[x,0] == 0.5:
        scaled_df.iloc[x,0] = 2;
    if scaled_df.iloc[x,0] == 1.0:
        scaled_df.iloc[x,0] = 3;

# %% [markdown]
# > 1 -> Setosa
#
# > 2 -> Versicolor
#
# > 3 -> Verginica
#
# **Estos seran nuestros targets en el proceso de clasificación**

# %%
scaled_df
# Out:
#      Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0           0.0     0.045455      0.070175     0.736842      0.242424
# 1           0.0     0.045455      0.070175     0.473684      0.181818
# 2           0.0     0.793780      0.052632     0.578947      0.121212
# 3           0.0     0.793780      0.087719     0.526316      0.090909
# 4           0.0     0.793780      0.070175     0.789474      0.212121
# ..          ...          ...           ...          ...           ...
# 146         3.0     1.000000      0.736842     0.473684      0.727273
# 147         3.0     0.818182      0.701754     0.210526      0.606061
# 148         3.0     0.863636      0.736842     0.473684      0.666667
# 149         3.0     1.000000      0.771930     0.684211      0.575758
# 150         3.0     0.772727      0.719298     0.473684      0.484848
#
#         Comp2     Comp3
# 0    0.739130  0.110246
# 1    0.956522  0.058366
# 2    0.782609  0.058366
# 3    0.956522  0.088846
# 4    0.484149  0.497372
# ..        ...       ...
# 146  0.043478  0.797665
# 147  0.043478  0.590143
# 148  0.043478  0.797665
# 149  0.776583  0.981842
# 150  0.776583  0.473956
#
# [151 rows x 7 columns]

# %% [markdown]
# # Guardamos el nuevo Dataset

# %%
new_df = scaled_df

# %%
new_df.to_excel('new_df.xlsx')

# %% [markdown]
# # Trabajamos con Este nuevo Dataset

# %%
dataset = new_df

# %%
dataset
# Out:
#      Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0           0.0     0.045455      0.070175     0.736842      0.242424
# 1           0.0     0.045455      0.070175     0.473684      0.181818
# 2           0.0     0.793780      0.052632     0.578947      0.121212
# 3           0.0     0.793780      0.087719     0.526316      0.090909
# 4           0.0     0.793780      0.070175     0.789474      0.212121
# ..          ...          ...           ...          ...           ...
# 146         3.0     1.000000      0.736842     0.473684      0.727273
# 147         3.0     0.818182      0.701754     0.210526      0.606061
# 148         3.0     0.863636      0.736842     0.473684      0.666667
# 149         3.0     1.000000      0.771930     0.684211      0.575758
# 150         3.0     0.772727      0.719298     0.473684      0.484848
#
#         Comp2     Comp3
# 0    0.739130  0.110246
# 1    0.956522  0.058366
# 2    0.782609  0.058366
# 3    0.956522  0.088846
# 4    0.484149  0.497372
# ..        ...       ...
# 146  0.043478  0.797665
# 147  0.043478  0.590143
# 148  0.043478  0.797665
# 149  0.776583  0.981842
# 150  0.776583  0.473956
#
# [151 rows x 7 columns]

# %%
dataset['Species_name'] = species_names ##add target feature

# %%
dataset['Species_name'][103] = ' Verginica'
dataset['Species_name'][104] = ' Verginica'
dataset['Species_name'][105] = ' Verginica'
dataset['Species_name'][106] = ' Verginica'
dataset['Species_name'][150] = ' Verginica'
# Out:
# <ipython-input-102-7baf67c5b23c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Species_name'][103] = ' Verginica'
# <ipython-input-102-7baf67c5b23c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Species_name'][104] = ' Verginica'
# <ipython-input-102-7baf67c5b23c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Species_name'][105] = ' Verginica'
# <ipython-input-102-7baf67c5b23c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Species_name'][106] = ' Verginica'
# <ipython-input-102-7baf67c5b23c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Species_name'][150] = ' Verginica'

# %% [markdown]
# # Implemenación Support Vector Machines
#
# Steps:
#
# > Seperate features and target
#
# > Create the network
#
# > Fit model
#
# > Test model

# %%
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import LabelBinarizer
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# %%
X = dataset.drop(['Species_No', 'Species_name'], axis=1) #drop target row 
y = dataset['Species_name']  #select target row (terget)

# %%
#el traget es de tipo STRING, debemos codificarla
encoder = LabelEncoder()
encoder.fit(y)
encoded_y = encoder.transform(y)
# convert integers to dummy variables (i.e. one hot encoded)
y = np_utils.to_categorical(encoded_y)

# %%
from sklearn.model_selection import train_test_split
#make split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2) #80% de la data para train | 20% de la data para test

# %% [markdown]
# ## Creamos el modelo

# %%
# Creating a model
model = Sequential()
model.add(Dense(10, input_dim=6, activation='relu'))   # input_dim = 6 ya que tenemos 6 caracteristicas 
model.add(Dense(10, activation='relu'))
model.add(Dense(3, activation='softmax'))    # la densidad de la salida es 3 porque tenemos 3 clases que podemos clasificar

# Compiling model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=300, batch_size=10)  #entrenamos el modelo
# Out:
# Epoch 1/300
# 12/12 [==============================] - 0s 625us/step - loss: 1.2185 - accuracy: 0.0605
# Epoch 2/300
# 12/12 [==============================] - 0s 563us/step - loss: 1.2193 - accuracy: 0.1013
# Epoch 3/300
# 12/12 [==============================] - 0s 571us/step - loss: 1.1535 - accuracy: 0.3438
# Epoch 4/300
# 12/12 [==============================] - 0s 597us/step - loss: 1.1246 - accuracy: 0.3786
# Epoch 5/300
# 12/12 [==============================] - 0s 787us/step - loss: 1.1306 - accuracy: 0.2872
# Epoch 6/300
# 12/12 [==============================] - 0s 828us/step - loss: 1.0826 - accuracy: 0.3660
# Epoch 7/300
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0672 - accuracy: 0.3219
# Epoch 8/300
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0597 - accuracy: 0.3383
# Epoch 9/300
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0391 - accuracy: 0.4023
# Epoch 10/300
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0278 - accuracy: 0.4344
# Epoch 11/300
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0023 - accuracy: 0.4517
# Epoch 12/300
# 12/12 [==============================] - 0s 1ms/step - loss: 0